# %% [markdown]
# **Q1: Reading data from files**
#
# a. Read the data in the file weatherAUS.csv into a Python dictionary
#
# b. Show the first 5 lines to show that the data has been read in

# %%
# a.
import csv

with open('weatherAUS.csv') as dataFile:
    dreader = csv.DictReader(dataFile)

# %%
# b.
import pandas as pd
csv_file = 'weatherAUS.csv'
we = pd.read_csv(csv_file)

ffLine = pd.read_csv('weatherAUS.csv', nrows=5)
print(ffLine)
# Out:
#       Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  1/12/08   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2/12/08   Albury      7.4     25.1       0.0          NaN       NaN
# 2  3/12/08   Albury     12.9     25.7       0.0          NaN       NaN
# 3  4/12/08   Albury      9.2     28.0       0.0          NaN       NaN
# 4  5/12/08   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W             44          W  ...          22       1007.7
# 1         WNW             44        NNW  ...          25       1010.6
# 2         WSW             46          W  ...          30       1007.6
# 3          NE             24         SE  ...          16       1017.6
# 4           W             41        ENE  ...          33       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %% [markdown]
# ## Q2: Creating functions

# %% [markdown]
# a. Write a function called daysOver that takes three arguments: a dictionary, a location
# (such as ‘Sydney’, ‘Adelaide’,etc) and a temperature and returns the number of days
# that were over the given temperature for the given location.

# %%
we
# Out:
#            Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       1/12/08   Albury     13.4     22.9       0.6          NaN       NaN
# 1       2/12/08   Albury      7.4     25.1       0.0          NaN       NaN
# 2       3/12/08   Albury     12.9     25.7       0.0          NaN       NaN
# 3       4/12/08   Albury      9.2     28.0       0.0          NaN       NaN
# 4       5/12/08   Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...      ...       ...          ...       ...
# 142188  20/6/17    Uluru      3.5     21.8       0.0          NaN       NaN
# 142189  21/6/17    Uluru      2.8     23.4       0.0          NaN       NaN
# 142190  22/6/17    Uluru      3.6     25.3       0.0          NaN       NaN
# 142191  23/6/17    Uluru      5.4     26.9       0.0          NaN       NaN
# 142192  24/6/17    Uluru      7.8     27.0       0.0          NaN       NaN
#
# ...

# %%
we = pd.read_csv(csv_file, usecols=["Location","MaxTemp"])
we
# Out:
#        Location  MaxTemp
# 0        Albury     22.9
# 1        Albury     25.1
# 2        Albury     25.7
# 3        Albury     28.0
# 4        Albury     32.3
# ...         ...      ...
# 142188    Uluru     21.8
# 142189    Uluru     23.4
# 142190    Uluru     25.3
# 142191    Uluru     26.9
# 142192    Uluru     27.0
#
# [142193 rows x 2 columns]

# %%
we.to_csv("LoMaxT.csv",index=False)
we2 = pd.read_csv("LoMaxT.csv")
we2
# Out:
#        Location  MaxTemp
# 0        Albury     22.9
# 1        Albury     25.1
# 2        Albury     25.7
# 3        Albury     28.0
# 4        Albury     32.3
# ...         ...      ...
# 142188    Uluru     21.8
# 142189    Uluru     23.4
# 142190    Uluru     25.3
# 142191    Uluru     26.9
# 142192    Uluru     27.0
#
# [142193 rows x 2 columns]

# %%
def daysOver(LoMaxT, Location, MaxTemp):
    d = 0
    if LoMaxT['MaxTemp']>= 28:
        d = d + 1
        print(d)

LoMaxT = we2
Loc = (input('Please enter a location: '))


days = daysOver(we2, Loc, d)
print(days)
# Out:
# Please enter a location: Adelaide
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8e18caff54be> in <module>
#       9
#      10
# ---> 11 days = daysOver(we2, Loc, d)
#      12 print(days)
#
# NameError: name 'd' is not defined

# %% [markdown]
# ###
