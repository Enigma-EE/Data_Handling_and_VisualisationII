# %% [markdown]
# ## Section 1 – More blood Glucose Data

# %% [markdown]
# A simulated blood glucose readings for 500 persons without diabetes.
# * The normal values are below 126 mg/dL and over 60 mg/dL.

# %%
import random

limit = 501
value = random.randint(60,126)
x = 0

while x < 501:
    if x:
        value = random.randint(60,126)
        print('blood glucose reading is', value)
        print('sample ', x)
    x += 1
# Out:
# blood glucose readings 124
# sample  1
# blood glucose readings 66
# sample  2
# blood glucose readings 97
# sample  3
# blood glucose readings 75
# sample  4
# blood glucose readings 71
# sample  5
# blood glucose readings 60
# sample  6
# blood glucose readings 76
# sample  7
# blood glucose readings 120
# sample  8
# blood glucose readings 80
# sample  9
# blood glucose readings 112
# sample  10
# blood glucose readings 94
# sample  11
# blood glucose readings 115
# sample  12
# blood glucose readings 104
# sample  13
# blood glucose readings 85
# sample  14
# blood glucose readings 91
# sample  15
# blood glucose readings 61
# sample  16
# blood glucose readings 125
# sample  17
# blood glucose readings 118
# sample  18
# blood glucose readings 63
# sample  19
# blood glucose readings 99
# sample  20
# blood glucose readings 105
# sample  21
# blood glucose readings 76
# sample  22
# blood glucose readings 100
# sample  23
# blood glucose readings 70
# sample  24
# ...

# %% [markdown]
# ## Section 2 – Unit and data point chooser

# %% [markdown]
# In Australia, blood glucose levels are reported in mmol/L instead of mg/dL. The conversion is:
# mmol/L = (mg/dL) / 18
#
#  * Please specify the preferred unit (*a*.mmol/L **/** *b*.mg/dL)

# %%
import random

limit = 501
value = random.randint(60,126)
y = 0
unit = input("a.mmol/L; b.mg/dL: ")

while y < 501 and (unit != 'a' or unit != 'b'):
    value = random.randint(60,126)
    if unit == 'a':
            print("The blood glucose level is", round(value/18,2), "mmol/L")
            print('sample ', y)
         
    elif unit =='b':
            print("The blood glucose level is ", value, 'mg/dL')
            print('sample ', y)
    else :
        unit = input("Please enter a or b")
    y += 1
# Out:
# a.mmol/L; b.mg/dL: a
# The blood glucose level is 5.33 mmol/L
# sample  0
# The blood glucose level is 6.06 mmol/L
# sample  1
# The blood glucose level is 6.5 mmol/L
# sample  2
# The blood glucose level is 4.61 mmol/L
# sample  3
# The blood glucose level is 4.89 mmol/L
# sample  4
# The blood glucose level is 6.39 mmol/L
# sample  5
# The blood glucose level is 6.78 mmol/L
# sample  6
# The blood glucose level is 3.56 mmol/L
# sample  7
# The blood glucose level is 6.17 mmol/L
# sample  8
# The blood glucose level is 4.0 mmol/L
# sample  9
# The blood glucose level is 5.67 mmol/L
# sample  10
# The blood glucose level is 6.44 mmol/L
# sample  11
# The blood glucose level is 6.33 mmol/L
# sample  12
# The blood glucose level is 5.61 mmol/L
# sample  13
# The blood glucose level is 6.56 mmol/L
# sample  14
# The blood glucose level is 3.83 mmol/L
# sample  15
# The blood glucose level is 4.56 mmol/L
# sample  16
# The blood glucose level is 6.78 mmol/L
# sample  17
# ...

# %% [markdown]
# ## Section 3 – Giving more choices

# %%
import random
limit = int(input('Please enter the number +1 of data points the you requested: '))
value = random.randint(60,126)
z = 0
unit = input("a.mmol/L; b.mg/dL: ")

while z < limit and (unit != 'a' or unit != 'b'):
    value = random.randint(60,126)
    if unit == 'a':
            print("The blood glucose level is", value, "mmol/L")
            print('sample ', z)
         
    elif unit =='b':
            print("The blood glucose level is ", value, 'mg/dL')
            print('sample ', z)
        
    else :
        unit = input("Please enter a or b")
    z += 1
# Out:
# Please enter the number +1 of data points the you requested: 10
# a.mmol/L; b.mg/dL: a
# The blood glucose level is 116 mmol/L
# sample  0
# The blood glucose level is 114 mmol/L
# sample  1
# The blood glucose level is 116 mmol/L
# sample  2
# The blood glucose level is 116 mmol/L
# sample  3
# The blood glucose level is 106 mmol/L
# sample  4
# The blood glucose level is 85 mmol/L
# sample  5
# The blood glucose level is 64 mmol/L
# sample  6
# The blood glucose level is 94 mmol/L
# sample  7
# The blood glucose level is 91 mmol/L
# sample  8
# The blood glucose level is 91 mmol/L
# sample  9
