# %% [markdown]
# ##  Q1 Plotting Panda Data Frames with Date indexes
#
#
# **1. Create six time series stored in a Pandas data frame:**\
#    a. The data frame must have an index that is a range of dates from 2016-01-01 until today.\
#    b. Each column contains one set of random numbers in a range 0 to 1 (each column will have
#    one random number for each date).

# %%
import pandas as pd
import numpy as np

dateRange1 = pd.date_range('2016-01-01','2016-12-31')
numberGen1 = len(dateRange1)
timeS1 = pd.Series(np.random.random(numberGen1), index = dateRange1)
timeFrame1 = pd.DataFrame(timeS1, columns = ['data'])

dateRange2 = pd.date_range('2017-01-01','2017-12-31')
numberGen2 = len(dateRange2)
timeS2 = pd.Series(np.random.random(numberGen2), index = dateRange2)
timeFrame2 = pd.DataFrame(timeS2, columns = ['data'])

dateRange3 = pd.date_range('2018-01-01','2018-12-31')
numberGen3 = len(dateRange3)
timeS3 = pd.Series(np.random.random(numberGen3), index = dateRange3)
timeFrame3 = pd.DataFrame(timeS3, columns = ['data'])

dateRange4 = pd.date_range('2019-01-01','2019-12-31')
numberGen4 = len(dateRange4)
timeS4 = pd.Series(np.random.random(numberGen4), index = dateRange4)
timeFrame4 = pd.DataFrame(timeS4, columns = ['data'])

dateRange5 = pd.date_range('2020-01-01','2020-12-31')
numberGen5 = len(dateRange5)
timeS5 = pd.Series(np.random.random(numberGen5), index = dateRange5)
timeFrame5 = pd.DataFrame(timeS5, columns = ['data'])

dateRange6 = pd.date_range('2021-01-01','2021-05-19')
numberGen6 = len(dateRange6)
timeS6 = pd.Series(np.random.random(numberGen6), index = dateRange6)
timeFrame6 = pd.DataFrame(timeS6, columns = ['data'])

timeFrame1
# Out:
#                 data
# 2016-01-01  0.932677
# 2016-01-02  0.287279
# 2016-01-03  0.819723
# 2016-01-04  0.539267
# 2016-01-05  0.009872
# ...              ...
# 2016-12-27  0.579697
# 2016-12-28  0.141725
# 2016-12-29  0.660518
# 2016-12-30  0.531387
# 2016-12-31  0.033150
#
# [366 rows x 1 columns]

# %%
timeFrame = pd.DataFrame([timeS1,timeS2,timeS3,timeS4,timeS5,timeS6])

# %%
timeFrame2
# Out:
#                 data
# 2017-01-01  0.073078
# 2017-01-02  0.689382
# 2017-01-03  0.011797
# 2017-01-04  0.253307
# 2017-01-05  0.526813
# ...              ...
# 2017-12-27  0.666016
# 2017-12-28  0.216235
# 2017-12-29  0.663931
# 2017-12-30  0.034254
# 2017-12-31  0.253113
#
# [365 rows x 1 columns]

# %%
# 3 - 6
print(timeFrame3, timeFrame4, timeFrame5, timeFrame6)
# Out:
#                 data
# 2018-01-01  0.701436
# 2018-01-02  0.653213
# 2018-01-03  0.549938
# 2018-01-04  0.366091
# 2018-01-05  0.882834
# ...              ...
# 2018-12-27  0.668153
# 2018-12-28  0.531262
# 2018-12-29  0.455470
# 2018-12-30  0.073719
# 2018-12-31  0.276652
#
# [365 rows x 1 columns]                 data
# 2019-01-01  0.556046
# 2019-01-02  0.815840
# 2019-01-03  0.424232
# 2019-01-04  0.215364
# 2019-01-05  0.123577
# ...              ...
# 2019-12-27  0.445642
# 2019-12-28  0.650080
# 2019-12-29  0.751805
# 2019-12-30  0.639784
# 2019-12-31  0.671476
#
# [365 rows x 1 columns]                 data
# 2020-01-01  0.743424
# 2020-01-02  0.981409
# 2020-01-03  0.114624
# 2020-01-04  0.769453
# 2020-01-05  0.298043
# ...              ...
# 2020-12-27  0.259466
# 2020-12-28  0.179365
# 2020-12-29  0.998881
# 2020-12-30  0.529324
# 2020-12-31  0.002414
#
# [366 rows x 1 columns]                 data
# 2021-01-01  0.562651
# 2021-01-02  0.345855
# 2021-01-03  0.423451
# ...

# %% [markdown]
# **2. Calculate and print the number of days from 2016-01-01 until today.**

# %%
dateRange = pd.date_range('2016-01-01','2021-05-19')
days = len(dateRange)
print('The number of days from 2016-01-01 until today is',days,'days.')
# Out:
# The number of days from 2016-01-01 until today is 1966 days.

# %% [markdown]
# **3. Show the first 30 rows of your data (using a Pandas data frame function).**

# %%
dateRange = pd.date_range('2016-01-01','2021-05-19')
numberGen1 = len(dateRange)
timeS = pd.Series(np.random.random(numberGen), index = dateRange)
timeFrame = pd.DataFrame(timeS, columns = ['data'])

timeFrame.head(30)
# Out:
#                 data
# 2016-01-01  0.163463
# 2016-01-02  0.679580
# 2016-01-03  0.314414
# 2016-01-04  0.958055
# 2016-01-05  0.174474
# 2016-01-06  0.716115
# 2016-01-07  0.081844
# 2016-01-08  0.628571
# 2016-01-09  0.675292
# 2016-01-10  0.952972
# 2016-01-11  0.944209
# 2016-01-12  0.311987
# 2016-01-13  0.193769
# 2016-01-14  0.282892
# 2016-01-15  0.268375
# 2016-01-16  0.830962
# 2016-01-17  0.534224
# 2016-01-18  0.300270
# 2016-01-19  0.983310
# 2016-01-20  0.355076
# 2016-01-21  0.221409
# 2016-01-22  0.080643
# 2016-01-23  0.052377
# 2016-01-24  0.081077
# 2016-01-25  0.172755
# 2016-01-26  0.830358
# 2016-01-27  0.880330
# 2016-01-28  0.288595
# 2016-01-29  0.025486
# 2016-01-30  0.672280

# %% [markdown]
# **4. Calculate the cumulative sum of the Data frame (using the < DataFrame >.cumsum() function) and
# store it in a new data frame called: df_accumulate. Display the first five rows of your data to verify the values.**

# %%
df_accumulate = timeFrame.cumsum()
df_accumulate.head(5)
# Out:
#                 data
# 2016-01-01  0.163463
# 2016-01-02  0.843043
# 2016-01-03  1.157457
# 2016-01-04  2.115512
# 2016-01-05  2.289986

# %%
df_line = pd.DataFrame({0: df_accumulate1 =  timeFrame1.cumsum(),
                        1: df_accumulate2 =  timeFrame2.cumsum(),
                        2: df_accumulate3 =  timeFrame3.cumsum(),
                        3: df_accumulate4 =  timeFrame4.cumsum(),
                        4: df_accumulate5 =  timeFrame5.cumsum(),
                        5: df_accumulate6 =  timeFrame6.cumsum()}                       
                      )

plots=df_line.plot(style= ['r-','g--','b:','m-.','k:','c:*'],title='Six different line styles',figsize=(10,5)) 
plots.legend(legend_labels,loc='upper left')
# Out:
#   File "<ipython-input-132-c05c297882ea>", line 1
#     df_line = pd.DataFrame({0: df_accumulate1 =  timeFrame1.cumsum(),
#                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# **6. Plot the six sets of row values of df_accumulate in separate graphs using subplots
# then plot the accumulate sum of each of the columns (random numbers).**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


timeFrame1 = pd.DataFrame(timeS1, columns = ['data'])
timeFrame2 = pd.DataFrame(timeS2, columns = ['data'])
timeFrame3 = pd.DataFrame(timeS3, columns = ['data'])
timeFrame4 = pd.DataFrame(timeS4, columns = ['data'])
timeFrame5 = pd.DataFrame(timeS5, columns = ['data'])
timeFrame6 = pd.DataFrame(timeS6, columns = ['data'])

df_accumulate1 =  timeFrame1.cumsum()
df_accumulate2 =  timeFrame2.cumsum()
df_accumulate3 =  timeFrame3.cumsum()
df_accumulate4 =  timeFrame4.cumsum()
df_accumulate5 =  timeFrame5.cumsum()
df_accumulate6 =  timeFrame6.cumsum()

df_list = [df_accumulate1, df_accumulate2,df_accumulate3, df_accumulate4, df_accumulate5, df_accumulate6]

styles = ['r-','g--','b:','m-.','k:','c:*']

#You can define number of rows and columns for subplots
numberRow=3
numberCol=2

fig, axes = plt.subplots(numberRow, numberCol)
#Variable to counter to move in the list of the frames and display each of them  
counter=0 
for r in range(numberRow):
    for c in range(numberCol):
        df_list[counter].plot(ax=axes[r,c], style=styles[counter],figsize=(20,10))
        counter=counter+1

# %% [markdown]
# ## Q2 Manipulating mental health data

# %% [markdown]
# a) In your Jupyter Notebook read this file data into a Pandas data frame.
#
#  In your Jupyter Notebook read this file data into a Pandas data frame. Be sure to parse the
# Timestamp as a date time rather than a string.\
# Print the first five rows to show that the data has loaded and print the total number of rows
# using the shape property.\
# Write Python code to return the following data:\
# • Select all rows where the Age is less than 1\
# • Select all rows where the Age is greater than 99

# %%
data = pd.read_csv('survey.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.shape[0]
# Out:
# 1259

# %%
df.loc[df['Age'] < 1]
# Out:
#                 Timestamp   Age Gender         Country state self_employed  \
# 143   2014-08-27 12:39:14   -29   Male   United States    MN            No
# 715   2014-08-28 10:07:53 -1726   male  United Kingdom   NaN            No
# 1127  2014-08-30 20:55:11    -1      p   United States    AL           Yes
#
#      family_history treatment work_interfere    no_employees  ...  \
# 143              No        No            NaN  More than 1000  ...
# 715              No       Yes      Sometimes          26-100  ...
# 1127            Yes       Yes          Often             1-5  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 143           Don't know                        No                      No
# 715   Somewhat difficult                       Yes                      No
# 1127           Very easy                       Yes                     Yes
#
#          coworkers supervisor mental_health_interview phys_health_interview  \
# ...

# %%
df.loc[df['Age'] > 99]
# Out:
#                Timestamp          Age Gender        Country state  \
# 364  2014-08-27 15:05:21          329   Male  United States    OH
# 390  2014-08-27 15:24:47  99999999999    All       Zimbabwe   NaN
#
#     self_employed family_history treatment work_interfere no_employees  ...  \
# 364            No             No       Yes          Often         6-25  ...
# 390           Yes            Yes       Yes          Often          1-5  ...
#
#               leave mental_health_consequence phys_health_consequence  \
# 364      Don't know                     Maybe                      No
# 390  Very difficult                       Yes                     Yes
#
#         coworkers supervisor mental_health_interview phys_health_interview  \
# 364  Some of them         No                      No                    No
# 390            No         No                     Yes                    No
#
#     mental_vs_physical obs_consequence comments
# ...

# %% [markdown]
# b. Look at the Pandas data frame drop() function in the Pandas documentation Drop can be
# used to remove data from the data set.\
# Using your solutions from part a, drop the data values from your data set where the age is
# less than 1 or greater than 99.\
# • Print the shape of your new data frame using the shape property.\
# • Has the number of columns changed?\
# • Has the number of rows changed?\
# • Explain why each has or has not changed.

# %%
df.drop([143, 715, 1127, 364, 390], inplace=True)
# the total number of rows
print('the total number of rows: ', df.shape[0])
print('the total number of columns: ',len(df.columns))
# Out:
# the total number of rows:  1254
# the total number of columns:  27

# %% [markdown]
# The number of rows changed as 5 rows are droped.

# %% [markdown]
# c. Print the maximum, mean and minimum age values in your data.

# %%
print('the maximum age value =',df.Age.max())
print('the minimum age value =',df.Age.min())
print('the mean age value =',df.Age.mean())
# Out:
# the maximum age value = 72
# the minimum age value = 5
# the mean age value = 32.01913875598086

# %% [markdown]
# ## Q3 Plotting mental health data

# %% [markdown]
# a) Create a box plot showing the distribution of ages for \
# 1) people with no family history of mental illness, and \
# 2) people with a family history of mental illness.

# %%
df.boxplot(column=['Age'], by=['family_history'], figsize=(10,8))

# %% [markdown]
# ## Q4 Cleaning data

# %% [markdown]
# a. Have a look at the survey responses for gender. You will see that there are a wide variety of
# ways that respondents identify their gender. Some of these are clearly different ways of
# indicating the same gender, for example: ‘female’, ‘F’, ‘f’ and ‘Female’.

# %%
data = pd.read_csv('survey.csv')
df = pd.DataFrame(data)
df.drop([143, 715, 1127, 364, 390], inplace=True)
df.replace({'male': 'Male','M': 'Male','m': 'Male','Make': 'Male','Man': 'Male',
            'Mail': 'Male','Malr': 'Male','msle': 'Male','Mal': 'Male','maile': 'Male',
            'Male': 'Male','Cis Male': 'Male','Male(CIS)': 'Male', 'cis male': 'Male', 
            'Cis Man': 'Male', 'Guy (-ish) ^_^': 'Male','female':'Female','F':'Female','f':'Female',
            'Femake':'Female','woman':'Female','femail':'Female', 'Woman':'Female',
            'Cis Female':'Female','cis-female/femme':'Female','Female(cis)':'Female'})
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44    Male   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    Male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    Male   United States    CA            No
# 1257  2015-11-30 21:25:06   46  Female   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# b. plot using two pie plots:\
# • the proportion of Males that have sought/not sought treatment for a mental
# health condition\
# • proportion of Females that have sought/not sought treatment for a mental
# health condition

# %%
M = df.loc[df['Gender'] == 'Male']
M1 = pd.DataFrame(M, columns = ['Gender','treatment'])
M1.treatment.value_counts().plot.pie(autopct='%1.1f%%', 
                                            figsize=(10,8), 
                                            title = 'Treatment for a mental health condition pie plot',
                                            startangle=90,
                                            labels=['Yes','No'])

# %%
F = df.loc[df['Gender'] == 'Female']
F1 = pd.DataFrame(F, columns = ['Gender','treatment'])
F1.treatment.value_counts().plot.pie(autopct='%1.1f%%', 
                                            figsize=(10,8), 
                                            title = 'Treatment for a mental health condition pie plot',
                                            startangle=90,
                                            labels=['Yes','No'])

# %%
df.treatment.value_counts().plot.pie(autopct='%1.1f%%', 
                                            figsize=(10,8), 
                                            title = 'Treatment for a mental health condition pie plot',
                                            startangle=90,
                                            labels=['Yes','No'])
